# %%
import pickle
import pytesseract
from layoutparser.ocr import TesseractAgent
import numpy as np
import faiss
import pandas as pd
from sentence_transformers import SentenceTransformer
from IPython.display import display, HTML 
import os

# %% [markdown]
# ##### Getting all the pickle files
# * Getting all the pickle files as it contains text which we extracted from images in layout format
# * We had to run the earlier commands in google collab as there is no support for dectron2 by facebook for windows .It mainly supports Linux and Mac

# %%
# Define the directory path
directory_path = 'pickle_files/'

# List all items in the directory
all_items = os.listdir(directory_path)

# Filter out directories (optional)
file_names = [f for f in all_items if os.path.isfile(os.path.join(directory_path, f)) and f.endswith('.pkl')]
file_names
# Out:
# ['PMC3576793_00004.pkl',
#  'PMC3654277_00006.pkl',
#  'PMC3777717_00006.pkl',
#  'PMC3863500_00003.pkl',
#  'PMC3976938_00002.pkl',
#  'PMC4027932_00001.pkl',
#  'PMC4527132_00004.pkl',
#  'PMC4760359_00006.pkl',
#  'PMC4954804_00001.pkl']

# %% [markdown]
# ##### Tesseract
# * Here we perform Optical Character Recognition (OCR) on segmented images using Tesseract
# * We have to do it for every pickle file
# * Mainly we have got different co-ordinates for text according to Layouts which it follows to form paragraphs, sections, tables etc
# * We are mainly concerned with text

# %%
ocr_agent = TesseractAgent(languages='eng')

# %%
fileText_dict = {}
for file_name in file_names:
    listText = []
    layout =  pickle.load(open(f'{directory_path}{file_name}', 'rb'))
    # Extract text
    for block in layout:
        segment_image = (block
                        .pad(left=5, right=5, top=5, bottom=5)
                        .crop_image(image))
        listText.append(ocr_agent.detect(segment_image))
    fileText_dict[file_name]=listText

# %%
fileText_dict
# Out:
# {'PMC3576793_00004.pkl': ['3.8. Allergic Sensitization in Asthma. Fifty-nine patients (46\ndul, 18 cildsen) bad been previously daghosed wih\n‘uthma. The retaining 59 patients had not been diagnosed\nwith sethina Sensation to any allergen was deteed in\n58% of patents with asthma (34/59). Twenty-six (4%)\nof 59 paints wore sensitized to spring pollens (Table 3)\n‘Approtimatly all of the asthma patients (30%; 30/9)\nwere senlzed to perennial allergens. Seven percent of\npatients with asthmns (4/59) were sensitized only to spring.\n',
#   'Total igi Eosinophe cer\nik) _propertion (3)\n\nSpring andl olen meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\n',
#   '4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpecte Igh level does not always correspond with the\npallets symptoms, We found that approximately twice a\nany patients were senalzed ta both spring pollens and\npetenal allergens compared to patente senatied ony to\n{pring pollens. However many patients were asymplomatie\n1G perehnial allergens Expose to perennial allergens such\n‘house dist mite and ct and dog danduf tan important\npredisposing rise factor for asthita (4, Previous dlngosis\n[tas wae largely elated to serum ig levels and blood\ncecinophil conte [5-7], Even ln noeasthenatic. patients,\n\n',
#   '‘The average of total serum Ig levee was highest in 87-year\nolds and decreased with age Figure 3a)\n\n234, Blood Call Eosinophil Count. The blood cll eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\nSpring poles, whe it was sigeanly higher (57 = 04%)\nit pleats senaltized to bath perenoal allergens and sping\npollens (P= 00145, Mann-Whitney U text) (igure 20),\n{able 2). The blood cell eosinophil count showed the same\nreductive tendency (Figure 30).\n\n',
#   'Basinopils Counts (oo7). even in nonast mane Ppanents:\nfrway responsiveness (assesed using methacholine [8 is\nIncreased in some eases of allergic shunts ndieatng an\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nshust mite cockroach, and ragweed ian important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘en in anymplomalic pallens [5,1]. In other words, total\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\n[gE level and blood cell eosinophil counts wer sigacaty\nslevated in patients senstzed to both spring pollens and\nperennial allergens, as compared to pallet senalized only\n‘ospring plles. Therefore paint sensitized bth sping\npollens and perennial allergens might be at gretter risk of\nEeveoping arwsybyperresponsivenersor asthma\n‘Comnpzed toads, fewer children were sensitized only\nto spring pollens. Most children (approximately 80%) had\n',
#   '‘significantly highe\nTo asee hae\n\n',
#   '',
#   '‘Spring and fall pollens and perennial\n',
#   '‘with asthma, Mann-Whitney U test). Blood eosinophil cell\nProportion in paints with adhe war S4 + G6% In\n\npallets without ssn, the proportion was 29 +" 02%,\n\n',
#   'pollen, whe 16% (94/59) in patients without asthma were\nFenstzad exclusively totheae allergens. They seven perce\nfof patents wth previous asthma dlagnoss (2159) were\n‘esstzed wo both spring nd perennilalergns, which was\nFicote The te of entiation (determined by RAST) ignifcantly higher than tat observed in patients without\nTapanese cedar, Japanese cypress, and mites was affected by the 5Shans (2qhi 17/993) (P 0.0017, chi-squize tet)\n\n',
#   '',
#   '',
#   'Tait 2 Serum total IgE and blood cell eosinophil,\n'],
#  'PMC3654277_00006.pkl': ['perennial allergens compared to patients sensitized only to\n{pring pollens. However many pants wee asympomatic\n1b perennial allergens. Exposure to perennial lerens, such\nAshouse dust mite and cl and dog dandruf an portant\npredisposing factor fr asta [4], Previous dagnoss\nSanta was largely rated fo serum gE levels ad Hood\nfosinophit counts 5-7) Even in nonasthnaic pants,\nSway sespnsivenens (sessed using methacholine [5\nineretied in ome cases of allergle thins Indesign\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nairway byprtesponavenes [2 Alrwayhypertesponsive\nfess is suOngly related to elevated total serum Ige levels\n\n',
#   'Proportion in patients with asthma was S4 + @6%. In\npallets without ssn, the proportion was 29 +" 02%,\nFlood eosinophil cell proportion it patente with aha was\nsigncantly higher than those in patient without asthna\n(P= 0008, Mans-WhitneyU test)\n\n4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpecte Igh level does not always correspond with the\npallets symptoms, We found that approximately twice a\nFran patients were senatied to both spring pollens and\n',
#   '‘The average of total serum Ig levee was highest in 87-year\nolds and decreased with age Figure 3a)\n\n234, Blood Call Eosinophil Count. The blood cll eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\nSpring poles, whe it was sigeanly higher (57 = 04%)\n\nTh patents senalied to both perennial al\n\n',
#   'cetients mee Black error Ioewed. anne myer forest pond lock orem On Reo HP) UF = GL) 7, ch-eagmane Best).\nfate age. Bac arrow bea, gay arow hed; and black arrow Yen gal serum IgE levels patients with asthma were\n\nowe pas och rats peste 4477+ 491Uiml, while those inpatient without asthma\n\n',
#   'pollens (P = 0.0146, Mann-Whitney U test) (Figure 2(b),\n{able 2). The blood cell eosinophil count showed the same\nreductive tendency (Figure 30).\n\n5 Allegi Sensitzaion i Asthma. ity-nine patients (46\ndul, 18 cildsen) bad been previously daghosed wih\n{stha, The remaining 593 patients had not been diagnosed\n',
#   '‘with asthma. Sensitization to any allergen was detected in\n58% of patents with asthma (34/59). Twenty-six (4%)\nof 59 paints wore sensitized to spring pollens (Table 3)\n‘Approtimatly all of the asthma patients (30%; 30/9)\nwere senlzed to perennial allergens. Seven percent of\npatients with asthmns (4/59) were sensitized only to spring.\n',
#   'Spring andl olen mts30\n\nSpring pallens an perennial alergns 391.467\nFallen nd prea allergens\nSpeingand fl pln apd prema gg 1\nalesene\n',
#   'Taal gi Formopa aT\n(ie) _propertin\n\n',
#   'Ayana)\n\nsone pole, whl 16 (94503) in patents without asthina wee\n=. ‘Shodex totes deren Thr sven pence\n\n> see i pane wth a previous aha dagnos (299) wee\nsesed wo beh ering and perennial egg, which ws\n\nFroume the mate of sensation (etemined by RAST) 10 Sgnifcantly higher than lh observed in patents without\n\n',
#   '',
#   'Se ee.\neven in asymptomatic patients [5 13] In other words, total\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\nTer tevell and blood cell eosinophil counts were significantly\n\n',
#   'Compared to adults, fewer children were sensitized only\n\no spring pollens. Most children (approximately 80%) had\n\n',
#   '',
#   '‘Compared to adults, fewer children were sensitized only\n0 spring pallens. Most children (approximately 80%) had\n\n',
#   'pollens and perenn\n\nergens might be at greater risk\n\n',
#   'allergens might be at greater risk of\n\nteveloping strwayhyperespondveness or aston,\n‘Compared toads, fewer children were senized only\n\ntw spring pollens. Most ddr (approximately 80%) had\n',
#   'pollens and perennial allergens might be at greater rsh\n'],
#  'PMC3777717_00006.pkl': ['Spring andl olen meio 52409\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\n\nSpeingand fl plese and Peel oy. a1y gi gag\nalergene\n\n‘The average of total serum ig levee was highest in 8.17-ye\nolds and decreased with age Figure 3a)\n\n244, Blood Call Eosinophil Count. ‘The blood cll eosnoph\nnut wat alto compared between group. The eosnoph\n‘all proportion was £ 04% in patents sensitized ony\n\nher (87 # 04%\n\n',
#   '{in patients sensitized to both perennial allergens and sprin,\npollens (P = 00146, Mann-Whitney U text) (igure 2)\n“able 2). The blood cell eosinophil count showed thes\nreductive tendency (Figure 30).\n\n5 Allegi Sensitzaion i Asthma ity-nie patents (4\ndul, 8 chiles) bad been previously daghosed wil\ntsthma. The retaining 59 patients had not been diagnos\nwith sethina Sensation to any allergen was detected\n\n58% of patents with asthma (34/59). Twenty (4a\nof 59 paints wore sensitized to spring pollens (Table 3)\n‘Approtimatly Ball of the asi pallets (St; 30/59\nwere senulzed to perennial allergens. Seven percent 0\npallets with asta (439) wre sensitized only to spi\n\n',
#   '(P= 0.008, Mann-Whitney U test).\n\n4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpecte Igh level does not always correspond with the\npallets symptoms, We found that approximately twice a\nany patients were senalzed ta both spring pollens and\npetenal allergens compared to patente senatied ony to\n{pring pollens. However many patients were asymplomatie\n1G perehnial allergens Expose to perennial allergens such\n‘house dist mite and ct and dog danduf tan important\npredisposing rise factor for asthita (4, Previous dlngosis\n[tas wae largely elated to serum ig levels and blood\nfenioophil counts [5-7 Even in nonashintic patents\ndetay responsienes (asesed using methacholine [8) is\nIncreased in some eases of allergic shunts ndieatng an\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nshust mite cockroach, and ragweed ian important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘en in anymplomalic pallens [5,1]. In other words, total\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\n[gE level and blood cell eosinophil counts wer sigacaty\nslevated in patients senstzed to both spring pollens and\nperennial allergens, as compared to pallet senalized only\n‘ospring plles. Therefore paint sensitized bth sping\npollens and perennial allergens might beat grater rik of\nEeveoping arwsybyperresponsivenersor asthma\n‘Comnpzed toads, fewer children were sensitized only\nto spring pollens. Most children (approximately 80%) ad\n',
#   'Spring pole\nSpring pallens a praia alergene\n\nSpring andl pln and prea allergens\n\npan pe\n\nns The rte of sensation (determined by RAST) to\nse cede, pane ype and er an actedy he\nthe pat each ne erpecrcy\n\npollen, whe 16% (94/593) in patients without asthma\nFenstizad excsvey totheselergens. Thty-sevenp\nff patets with previous astima diagosl (22/59)\nesstzed wo both spring and perennial allergens, whic\nsigeicanly higher than tha observed in pallens\nAsthma (204 17/98) (P =0.0017, chi-square tes),\nMean otal serum ig even patients with ash\n4477+ 491UimL, while those inpatients without\nwere 231 ¢ 27 TUL (P= 00001 compared top\n‘with asthma, Mane-Whitney U test) Blood eosinoph\n',
#   'a\nTosa iGE Eovinophilcel patents without asthma, the proportion was 19 + 2%.\n—_______ tnt} propation (blood eosinophil el proportion in patients with asta was\n\n'],
#  'PMC3863500_00003.pkl': ['‘ness is strongly related to elevated total serum IgE levels,\n‘ven in seymplomati patente [5,1 In other words, tata\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\n[gE level and blood cell eosinophil counts wer sigacaty\n\nslevated in pollens and\n\n',
#   'Seteaing an iparcananesr at\n‘chorea ee che wee seed ony\nto, Samra wad ewe hilren were satin an\n',
#   '‘Table 2). The blood cell eosinophil count showed the same\nreductive tendency (igure 40)\n\n5 Allegi Sensitzaion i Asthma. ity-nine patients (46\ndul, 18 cildsen) bad been previously daghosed wih\n‘uthma. The retaining 59 patients had not been diagnosed\nwith sethina Sensation to any allergen was deteed in\n158% of patients with asthma (34/59). Twenty-six (44%)\n',
#   '‘of 59 patients were sensitized to spring pollens (Table 3).\n\n‘Approtimatly all of the asthma patients (30%; 30/9)\nwere senlzed to perennial allergens. Seven percent of\npatlents with asthma (4/59) were sensitized only to spring\n\n',
#   'eb 8 8\n\nSeman ae age\n\nSpring pole °\nSpring pallens a praia alergene «\nSpring andl pln and prea allergens ‘\n\noom The eof sentation (determin by RAST) to\nTapas cedar, apne pene snd er war acted by the\nSowthe pets each ate especie\n\nTal gE Formopaead\nik) _propertion (3)\n\nSpring andl olen meio 52409\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\n\nSpeingand fl plese and Peel oy. a1y gi gag\nalesene\n\n‘The average of total serum Ig levee was highest in 87-year\nolds and decreased with age Figure 3a)\n\n234, Blood Call Eosinophil Count. The blood cll eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\n“pring pollens, while it was significantly higher (37 + 04%),\n\npollen, whe 16% (94/593) inpatients without asta were\nFenstizad exlsvey totheselergens. They-seven percent\nff patents wath previous asthma diagnosis (22/59) were\nesctzed wo both spring and penal allergens which was\nsignificantly higher than that observed in patient without\nAsthma (204 17/98) (P =0.0017, chi-square tes),\n\n‘Mean otal serum ig level patente with athina were\n4477+ 491U/ml, while those in patient without asthma\nwere 231 ¢ 271ml (P= 00001 compared to patent\n‘ith asthma, Manz-Whitey U tet) Blood eosinophil cll\nProportion in paints with asthma was S4 + 6M In\npallets without ssn, the proportion was 29 +" 02%,\nFlood eoriophil cll proportion in pallens wit ath was\nsignfcantly higher than those in patent witout asthma\n(P= 0008, Mans-WhitneyU test)\n\n4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpectte igh level does not always corespond wih he\npallets symptoms. We found that approxima twice a\nany pallens were seized to both spring pollens and\npetenal allergens compared to pallente senszed only to\n{pring pollens. However many paints were asympomatc\n1G perehnlalalergene Expose to perennial allergens, ach\nshout dist mite and et and dog danduf an important\npredisposing ce factor for ashi (4, Previous diagnos.\ncast wae largely related to serum ig levels and Blood\nfenioophil counts [5-7 Even in nonashintic patents\nety responsivenes (asesed using methacholine [8)\nIncreased in some cass of allergic shins ndeating an\nSnconesed stok for aefionn [9-11]. Seastesiicn to-cet Gamat\n\n',
#   '',
#   'station (etme by RAST) to\nespecie\n',
#   'he an el\n',
#   'Japanese cedar, Japanese «\n',
#   '‘specific IgE level, does\nfates symptoms We\npatients symptoms. We fc\n',
#   '',
#   '‘with asthma, Mann-Whitn\nProportion in pallnts wi\npatents without asta, 1\nFlood eorinophil cll prop\nsaya ha\n\na0, Mata Whitney\n\n‘4. Discussion\n',
#   'a IgE levels was highest in 8-17-year\n',
#   '477 + 891U/mL, whih\n',
#   '',
#   '‘spring pollens, w\n\n',
#   '',
#   'Spege Sl pe\nSpring pallens\n',
#   'tization (tied by RAST) to\nrespect\n',
#   '‘with asthma, Man-Whita\nProportion in pallens wi\npatents without sth\nFlood eosinophil cell propo\nsay ae ha\n\na, Man Whitney\n\n4. Discussion\n',
#   '',
#   '',
#   'Ayana)\n\noom The eof sentation (determin by RAST) to\nTapas cedar, apne pene snd er war acted by the\nSowthe pets each ate especie\n\nTal gE Formopaead\nik) _propertion (3)\n\nSpring andl olen meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\nSpring andl pln pd prea\nalergene\n\n‘The average of total serum Ig levee was highest in 87-year\nolds and decreased with age Figure 3a)\n\n234, Blood Call Eosinophil Count. The blood cll eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\nspting pollens, while it was significantly higher (5.7 + 0.4%)\n\npollen\npat\nsigs\nthm\n\nMi\nvith\npropo\nfatlen\nBlood\nsigs\n0\n\n4.Di\n\nleg\n‘pect\npatlen\nEy\nprea\n‘pring\ntaper\nshou\nedi\nteat\nfew\n',
#   'tiation (termined by RAST)\n\nrag tare\nik) _propertion (3)\nslaergens 91467 54405\n\nog levee was highest in 87-year\nge Figure Sa)\n\nit Count. The blood cell eosinophil\nsd cee teneen the soleil\n',
#   'age (Figure 3(a)).\n',
#   '',
#   'Spring pole\nSpring pallens a praia alergene\n\nSpring andl pln and prea allergens\n\npollen, whe 16% (94/593) in patients without asthma\nFenstized exchsvey to these allergens. Thirty-seven pe\nff patents wth previous asthma diagnos (22/59)\n‘esctzed to both spring and perennial allergens, which\nsignificantly higher than that observed in patent with\nAsthma (204 17/98) (P =0.0017, chi-square tes),\n\nMean otal seri level patents wih athena w\n4477+ 491ml, while thse inpatients without ath\nWere 224 + 271UimL (P= 0.0001 compared to pat\nWith asthma, Manz Whitey U test) Blood cosinop\nProportion in paints with asthma was 54 + 46%\npallets without ssthna, the proportion wis 29\nFlood eosinophil cell proportion in patents with shina\nsignficantly higher than thove in patent without ash\n(P= 0008, Mans-WhitneyU test)\n\n4. Discussion\n\nAllesgle sensitization, as diagnosed by the serum alle\nfpecte igh lve, docs not always corespond wit\n\npallets symptoms. We found that approximately tice\nany pallens were senlzed to both spring pollens\ntena allergens compared to pallens sented onl\nSpring pollens. However many paints were aston\n1 perehnlallergene Expose to perennial allergeng\n‘house dst mite and et and dog dandruf an impor\nPredsposng ra factr for ash [Previous dgn\n‘taste largely related to serum ig level and Bl\nfenioophil counts [5-7]. Even in nonashnaic pate\ndeway responsiveness (asesed using methacholine [8]\nIncreased in some cass of allergic shits, ndiating\n\nIncresed rik for athina 9-1 Sentization to cat dandr\n',
#   '',
#   '',
#   ''],
#  'PMC3976938_00002.pkl': ['‘Compared to adults, fewer children were sensitized only\nto spring pollens. Most children (approximately 80%) had\n\n',
#   'ee an 210m oa ample\n‘ih tM ioe tet). Bed csp eal\nTodeonoplcal repricnepsn th asma wes\nSion higher hat those in Pats wou sthma\nFania act reer\n\n',
#   '3.8. Allergic Sensitization in Asthma. Fifty-nine patients (46\ndul, 18 cildsen) bad been previously daghosed wih\n‘uthma. The retaining 59 patients had not been diagnosed\nwith sethina Sensation to any allergen was deteed in\n58% of patents with asthma (34/59). Twenty-six (4%)\nof 59 paints wore sensitized to spring pollens (Table 3)\n‘Approtimatly all of the asthma patients (30%; 30/9)\nwere senlzed to perennial allergens. Seven percent of\npatients with asthma (4/59) were sensitized only to spring\n',
#   'Allergic sensitization, as diagnosed by the serum allergen-\nfpecte Igh level does not always correspond with the\npallets symptoms, We found that approximately twice a\nany patients were senalzed ta both spring pollens and\npetenal allergens compared to patente senatied ony to\n{pring pollens. However many patients were asymplomatie\n1G perehnial allergens Expose to perennial allergens such\n‘house dist mite and ct and dog danduf tan important\npredisposing rise factor for asthita (4, Previous dlngosis\n[tas wae largely elated to serum ig levels and blood\nfenioophil counts [5-7 Even in nonashintic patents\ndetay responsienes (asesed using methacholine [8) is\nIncreased in some eases of allergic shunts ndieatng an\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nshust mite cockroach, and ragweed ian important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘ven in seymplomati patente [5,1 In other words, tata\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\n[gE level and blood cell eosinophil counts wer sigacaty\nslevated in patients senstzed to both spring pollens and\nperennial allergens, as compared to pallet senalized only\n‘ospring plles. Therefore paint sensitized bth sping\npollens and perennial allergens might beat grater rik of\nEeveloping alway hyperesponsivenes or asa.\n\n',
#   '‘Ficuns i The sate of sensitization (determined by RAST) to\nTapas cedar, apne pene snd er war acted by the\nShow the pes ofeach ate respecte\n',
#   '44. Blood Cell Eosinophil Count. The blood cell eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\nSpring poles, whe it was sigeanly higher (57 = 04%)\nit pleats senaltized to bath perenoal allergens and sping\npollens (P= 00145, Mann-Whitney U text) (igure 20),\n{able 2). The blood cell eosinophil count showed the same\nreductive tendency (Figure 36).\n',
#   'pollen, while 16% (94/593) in patients without asthma were\nFenstzad exclusively totheae allergens. They seven perce\nfof patents wth previous asthma dlagnoss (2159) were\n‘esstzed wo both spring nd perennilalergns, which was\nsignificantly higher than that observed in ples witout\n‘asthma (20%; 117/593) (P = 0.0017, chi-square test)\n\n',
#   '4. Discussion\n',
#   'Tait 2 Serum total IgE and blood cell eosinophil,\n',
#   '',
#   '‘The average of total serum IgE levels was highest in 8-17-year\n‘olds and decreased with age (Figure 3a).\n',
#   '',
#   'ik) _propertion (3)\n\nSpring l pollens meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\nSpeingand fl plese and Peel oy. a1y gi gag\n',
#   'Spring andl pene\nSpring pallens a praia alergene\nSpring andl pln and prea allergens\n\n',
#   'Spring andl pene\nSpring pallens a praia alergene\nSpring andl pln and prea allergens\n\n',
#   'Theale Eosinophil ea\nisk) _propertion\n\nSpring l pollens meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\nSpeingand fl plese and Peel oy. a1y gi gag\n',
#   'Spring andl pene\nSpring pallens a praia alergene\nSpring andl pln and prea allergens\n',
#   'Total IgE" Eosinophil cell\nisk) _propertion\n\nSpring l pollens meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\nSpring andl pln pd prea\n',
#   '‘Total IgE Eosinophil ce\nie) proper\n\nSpring andl olen meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\nSpring andl pln pd prea\nalesene\n\n',
#   'ese 8 8\n\n‘Semon see sage (8)\n\noom The eof sentation (determin by RAST) to\nTapas cedar, apne pene snd er war acted by the\nSowthe pets each ate especie\n\nTal gE Formopaead\nik) _propertion (3)\n\nSpring andl olen meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\n'],
#  'PMC4027932_00001.pkl': ['adults, 15 chiiisen) Thad been pooviowsly Glagnoced with\n‘uthma. The retaining 59 patients had not been diagnosed\nwith sethina Sensation to any allergen was deteed in\n58% of patents with asthma (34/59). Twenty-six (4%)\nof 59 paints wore sensitized to spring pollens (Table 3)\n‘Approtimatly all of the asthma patients (30%; 30/9)\nwee senutzed to perennial allergens. Seven percent of\npallets with asthma (439) wre sensitized only to sping\n',
#   'perenniel allergens, os compared to pationts constiined only\nto spring polls. Therefore pallens sensitized to bth sping\npollens and perennial allergens aught be a greater rick of\nUeveoping alewaybyperresponsivenersor asthma\n‘Comnpzed toads, fewer children were sensitized only\nto sping pollens. Most cilren (approximately 80%) ad\n\n',
#   '444. Bload Call Eosinophil Count. The blood cel eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 204% inpatients sensed ony\nSpring poles, whe it was sigeanly higher (57 = 04%)\ni patents senaized to bath perennial alrgens and spring\npollens (P= 00145, Mann-Whitney U text) (igure 20),\n{able 2). The blood cell eosinophil count showed the same\nreductive tendency (Figure 30).\n\n‘5. Allergic Sensitization in Asthena. Fifty-nine patients (46\n',
#   'IgE levels and be\nee wate\n',
#   'eb 8 8\n\nSemen rat spe\n\noom The eof sentation (determin by RAST) to\nTapas cedar, apne pene snd er war acted by the\nSowthe pets each ate especie\n\nik) _propertion (3)\n\nSpring andl olen meio 52409\n\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\nSpring andl pln pd prea\nalergene\n\n‘The average of total serum Ig levee was highest in 87-year\ncolds and decreased with age (Figure 33)\n',
#   'sensitized to both spring and perennial allergens, which was\nwre ah 2 tun eat eared pens\nSih aitinaMuiacy et. Bedconof\nSisitinaclfpepricnt patent ashes es\n‘nitty he a ths patents toa ta\nTeer ee nite\n\n4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpecte Igh level does not always correspond with the\npallets symptoms, We found that approximately twice a\nany patients were senalzed ta both spring pollens and\npetenal allergens compared to patente senatied ony to\n{pring pollens. However many patients were asymplomatie\n1G perehnial allergens Expose to perennial allergens such\n‘house dist mite and ct and dog danduf tan important\npredisposing rise factor for asthita (4, Previous dlngosis\n[tas wae largely elated to serum ig levels and blood\nfenioophil counts [5-7 Even in nonashintic patents\ndetay responsienes (asesed using methacholine [8) is\nIncreased in some eases of allergic shunts ndieatng an\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nshust mite cockroach, and ragweed ian important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘en in anymplomalic pallens [5,1]. In other words, total\n\nserum ig level te considered an indcator of probable airway\n\n',
#   '',
#   'en, while 16% (94/95) sn patients without asthma we\nnated exchsvely to these lergens. Thty-seven perce\n\n',
#   'en, whe 16% (04/588) n pallens without asthma We\nied exclusively tothetellergen. Thirty-seven prc\n‘cadloata aalthe 0 tuaphons eotha’n duemmnns tatans sae\n',
#   'pollen, whe 16% (94/59) in patients without asthma were\nFenstzad exclusively totheae allergens. They seven perce\nfof patents wth previous asthma dlagnoss (2159) were\n‘esstzed wo both spring nd perennilalergns, which was\nsignificantly higher than that observed in ples witout\nAsthma (204 17/98) (P =0.0017, chi-square tes),\n\n‘Mean otal seri eves in patients with ashen were\n477 + 491U/mL, while thove in patients without aha\nwere 234 + 271ml (P= 0.0001 compared to patents\n‘sith asthma, Mans Whitney U tet) Blood eosinophil cll\nProportion in paints with adhe war S4 + G6% In\npallets without ssn, the proportion was 29 +" 02%,\nFlood eosinophil cell proportion it patente with aha was\nsigncantly higher than those in patient without asthna\n(P= 0008, Mans-WhitneyU test)\n\n4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpecte Igh level does not always correspond with the\npallets symptoms, We found that approximately twice a\nany patients were senalzed ta both spring pollens and\npetenal allergens compared to patente senatied ony to\n{pring pollens. However many patients were asymplomatie\n1G perehnial allergens Expose to perennial allergens such\n‘house dist mite and ct and dog danduf tan important\npredisposing rise factor for asthita (4, Previous dlngosis\n[tas wae largely elated to serum ig levels and blood\nfenioophil counts [5-7 Even in nonashintic patents\ndetay responsienes (asesed using methacholine [8) is\nIncreased in some eases of allergic shunts ndieatng an\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nshust mite cockroach, and ragweed ian important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘en in anymplomalic pallens [5,1]. In other words, total\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\n[gf levels and blood cell eosinophil counts were significantly\n\n',
#   '',
#   '',
#   '',
#   ''],
#  'PMC4527132_00004.pkl': ['See vendttald to perish allergen Gemen tela of Commande adit tte chidcen were areal\n\n',
#   '‘ages\ninnate\npan pe\n',
#   'cramer shad neta cap ima Papin aba\nOf patents wth previous ath dagnss (215) we\n‘of patients with & previous asthma diagnosis (22/59) we\n',
#   '',
#   'JTspanese cedar, Japanese cypress, and mites was affected by the\n‘Rothe pe cach ate respecte\n\nTal gE Formopaead\nik) _propertion (3)\n\nSpring andl olen meio 52409\nSpringpllensandperenialalrgens 391467 S405,\nFallen nd prea allergens\n\nSpeingand fl plese and Peel oy. a1y gi gag\nalesene\n\n‘The average of total serum Ig levee was highest in 87-year\nolds and decreased with age Figure 3a)\n\n234, Blood Call Eosinophil Count. The blood cll eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\nSpring poles, whe it was sigeanly higher (57 = 04%)\nit pleats senaltized to bath perenoal allergens and sping\npollens (P = 0.014, Mans Whatney U tes) (gure 20),\n{able 2). The blood cell eosinophil count showed the same\nreductive tendency (Figure 30).\n\n5 Allegi Sensitzaion i Asthma. ity-nine patients (46\ndul, 18 cildsen) bad been previously daghosed wih\n‘uthma. The retaining 59 patients had not been diagnosed\nwith sethina Sensation to any allergen was detected\n\n‘58% of patients with asthma (44/59). Twenty-six (44%)\n\n-erpgeys App ap olhnp bape nnghytnl seam\nasthma (20% 117/593) (P = 0.0017, chi-square ts).\n\n‘Mean otal serum ig level patente with athina were\n4477+ 491U/ml, while those in patient without asthma\nWere 24 + 271UimL. (P= 0.0001 compared to patents\n‘ith asthma, Manz-Whitey U tet) Blood eosinophil cll\nProportion in paints with asthma was S4 + 6M In\npallets without ssn, the proportion was 29 +" 02%,\nFlood eoriophil cll proportion in pallens wit ath was\nsignfcantly higher than those in patent witout asthma\n(P= 0008, Mans-WhitneyU test)\n\n4. Discussion\n\nAllesglesesitcton, as diagnosed by the serum allergen\nfpectte igh level does not always corespond wih he\npallets symptoms. We found that approxima twice a\nany pallens were seized to both spring pollens and\npetenal allergens compared to pallente senszed only to\n{pring pollens. However many paints were asympomatc\n1G perehnlalalergene Expose to perennial allergens, ach\nshout dist mite and et and dog danduf an important\npredisposing ce factor for ashi (4, Previous diagnos.\ncast wae largely related to serum ig levels and Blood\nfenioophil counts [5-7 Even in nonashintic patents\nety responsivenes (asesed using methacholine [8)\nIncreased in some cass of allergic shins ndeating an\n‘ncreasedriskfor asthma [9-H] Sensitization cat andra\ndhst mite cockroach, and ragweed isan important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘ven in seymplomati patents [, 13). In other words, ttl\nerura ig level te considered an indlcator of probable airway\nIyperesponsiveness oe asthma, In our stay otal serum\n[gE level and blood cell eoanophil counts wer sgnfcany\nslevted in patients eensized to both spring pollens and\nperennial allergens, as compared to paint senatized only\nto spring pollens. Therefore. patients sensitized to both spring\n\n',
#   'pollen, while\nfcr arp\n',
#   'Spring anc! fal pollens and perennial allergens:\n\n',
#   'Spring anc! fal pollens and perennial allergens:\n\n'],
#  'PMC4760359_00006.pkl': ['ness Is strongly related to elevated’ total serum Ugh leve’s,\neven in asyplomalie patients [5,13]. In other words, total\nter IgE levels considered an indicator of probable airy\nhyperesponsvenes or antuma. In our stu total serum\nig levee and blood cll eosinophil counts wee sgnfanly\nclevated in patients tenstized to both spring pollens and\nperennial allergens, a compared to pallens sensiized only\ntpring pollens. Therefore, patents sensed both spring\npelle nd perennial allergens might be at geser rik of\ndeveloping airway hyperesponsveness or stan,\n‘Compared to adults, fewer children were sensitized only\n\n',
#   'Perennia’ Bmergens compared 10 pabients sensitized’ only to\nspring pollens. However, many patients were asymptomatic\nth petenal allergens Enposute to perennial allergens sich\ntshouse dust mit and ca nd dog dandruf san important\npredisposing risk factor forathia [4 Previous dagnose\noat wa agelyelted to serum gE level and Blood\ncsinophil counts (5-7). Even in nonadhmatc patients,\nray esponsvenes (assessed using metbachaline [8]\nincreased in some cases of allergic shits indian an\nincreated riskfor sta [9-1]. Sensation teat dandrl,\ndust mite, cocsoach, and ragweed san important predictor\nof siswaybyperresponsivencs [1]. Airway hyperteponsive\nness s ctregly related to elevated total sexem Ige levels,\n\n',
#   'nf 59 patients were sensitized to spring pollens (Table 3).\nApproumatly bal of the asthma pallets (30%; 30/59)\nwore sensitiaed 10 perennial allergens. Seven percent of\n\n',
#   'The average of total serum IgE levels was highest in 8-17-year\nolds and decreased wit age (Figure la)\n\n24 Bod Call Esiophil Count. The blood cil eosinophil\ncount wat alto compared between groups. ‘The cosinaphl\ncl proportion was43 + 04% inpatients seni only to\nsen pollens, wl was sigalcail higher (87 + 04%)\nih patente sesitzed to both perennial allergens and spring\npallens (P = 0.0146, Mans: Whitey U test) (Pure 21),\nTable 2). The Mood cll eosinophil count showed the same\nreducive tendency (Figure 30),\n\n3.5. Allele Sensitization in Asthma. Piy-nine patents (46\nadulls, 15 children) had been previous diaghosed with\nsth The remaining $83 patients had not been diagnosed\nwith aha, Senatztion fo any allergen was detected in\n58% of patients with asthma (34/59). Twenty-six (44!\n\n',
#   '',
#   'A\n\nA\n\nA\n\n|\ni\ni\n:\n\nSpring pole o\nSpring pallens a praia alergene «\nSpring andl pln and prea allergens ‘\n\nAyana)\n\noom The eof sentation (determin by RAST) to\nTapas cedar, apne pene snd er war acted by the\nSowthe pets each ate especie\n\nTal gE Formopaead\nik) _propertion (3)\n\nSpring andl olen meio 52409\nSpringpllensandperenialalrgens 391467 S405,\n\n“pall potlens am perennial allergens\n\npollen, whe 16% (94/59) in patients without asthma were\nFenstzad exclusively totheae allergens. They seven perce\nfof patents wth previous asthma dlagnoss (2159) were\n‘esstzed wo both spring nd perennilalergns, which was\nsignificantly higher than that observed in ples witout\nAsthma (204 17/98) (P =0.0017, chi-square tes),\n\n‘Mean otal seri eves in patients with ashen were\n4477+ 491Uiml, while those inpatient without asthma\nWere 224 + 271UimL (P = 0.0001 compared to pasents\n‘sith asthma, Mans Whitney U tet) Blood eosinophil cll\nProportion in paints with adhe war S4 + G6% In\npallets without ssn, the proportion was 29 +" 02%,\nFlood eosinophil cell proportion it patente with aha was\nsigncantly higher than those in patient without asthna\n(P= 0008, Mans-WhitneyU test)\n\n4. Discussion\n\n“Allecgie\n\nsasitiztion, as diagnosed by the serum alleges\n',
#   'ee eee te ecific IgE level. does not always correspond wit\nSpring and fall pollens and perennial ‘specific IgE level, does not always correspond with\n\n‘Spring an ‘784213 61406 ——_atient’s symptoms. We found thar approxitaately twic\n',
#   '',
#   ''],
#  'PMC4954804_00001.pkl': ['',
#   'patients without sethmna, the prapection was 39 & 0.2%\nod eosinophil el proportion in patents with sth\nsigan higher than those in patents witout ash\n(P= 0008 Mann-Whitney U tet)\n\n4. Discussion\n\nAilemic ccxcittnatem. ta Hhamaied br “he torem dleeen\n',
#   'jneeetiglir wel eediedgeneel eve Mery sa\nspanese cea, Japanese eypresy and mies was affected by the\n\nTal gE Formopaead\nik) _propertion (3)\n',
#   'pollen, whe 16% (94/593) inpatients without asthma wes\nFenstizad exchsvey to these llergens. Thirty-seven perce\nff patents wth previous asthma diagnosl (22/59) wer\nfedstized to both spring and perennial allergens, which\nsignificantly higher than that observed in patient witha\nAsthma (204 17/98) (P =0.0017, chi-square tes),\n\nMean otal serum ig level patents wih ashen we\n477+ 491Uiml, while thse inpatient without aha\nWere 224 + 271UimL (P= 0.0001 compared to paten\n‘nth asthma, Manz-Whitey U tet). Blood eosinophil ce\n\nProportion in paints wilh atta was S4 + Q6% 1\n',
#   '‘The average of total serum IgF levels was highest in 8-17-year\nolds and decreased with age Figure 3a)\n\n234, Blood Call Eosinophil Count. The blood cll eosinophil\nunt was alto compared between groups. The ensngphil\n‘all proportion was 43 £ 04% in pallens senstized only to\nSpring poles, whe it was sigeanly higher (57 = 04%)\nit pleats senaltized to bath perenoal allergens and sping\npollens (P = 0.014, Mans Whatney U tes) (gure 20),\n{able 2). The blood cell eosinophil count showed the same\nreductive tendency (Figure 30).\n\n5 Allegi Sensitzaion i Asthma. ity-nine patients (46\ndul, 18 cildsen) bad been previously daghosed wih\n‘uthma. The retaining 59 patients had not been diagnosed\nwith sethina Sensation to any allergen was deteed in\n58% of patents with asthma (34/59). Twenty-six (4%)\n‘of 59 patients were sensitized to spring pollens (Table 3).\n\n‘fo perennial allergens. Exposure to perennial allergens, such\n‘house dist mite and ct and dog danduf tan important\npredisposing rise factor for asthita (4, Previous dlngosis\n[tas wae largely elated to serum ig levels and blood\nfenioophil counts [5-7 Even in nonashintic patents\ndetay responsienes (asesed using methacholine [8) is\nIncreased in some eases of allergic shunts ndieatng an\n‘ncreased risk for asthma [9-H] Sensitization o cat dandr uf\nshust mite cockroach, and ragweed ian important predictor\n‘fara bypertesponsivenes [2 Airway hypetesponiv\n‘ess atongly related to elevated ttl ser Ig level\n‘ven in seymplomati patente [5,1 In other words, tata\nserum ig level te considered an indcator of probable airway\nIyperesponsiveness oe asthma In our study tot serum\n[gE level and blood cell eosinophil counts wer sigacaty\nslevated in patients senstzed to both spring pollens and\nperennial allergens, as compared to pallet senalized only\n‘ospring plles. Therefore paint sensitized bth sping\npollens ed percnnial allerfens might be at greater rik af\n',
#   'proximately half of the asthma patients (50%; 30/59) developing airway hypertesponsiveness or asthma,\nse penshieed: Gs yoseiniel eisisas Gouin amen: of Comrade alti tone: vlaldoes ware saniend\n\n',
#   '‘many patients were sensitized to both spring pollens an\nreatlal allergens cornpared to patent venatoed only\n\n',
#   '',
#   'perLanrrrerids\n',
#   '',
#   'ring pollens and perennia! allergens 391467 = 54405\npoles an perennial lergene\n\n',
#   'ppatient’s symptoms. We foun\n',
#   'Spring and fal p\n',
#   '‘Spring and fal pollens and perennial allergens\n\n',
#   'Spring and fall p\n',
#   'Spring and fall pollens and perennial allergens\n\n',
#   '',
#   '‘Spring and fall pollens and perennial allergens\n\npollen, whe 16% (94/593) inpatients without asta we\nFenstizad exclusively totheaellergens. hey seven pete\nff patients wth previous asthma diagnosis (22/59) we\nsesstzed wo both spring and penal allergens which w\nsignificantly higher than that observed in patient witho\nAsthma (204 17/98) (P =0.0017, chi-square tes),\n\nMean otal serum ig level patente with shina we\n477+ 491U/ml, while thse in patente without ath\nwere 231 + 271m (P= 0.0001 compared to paten\nWith asthma, Manz Whitey U tet) Blood eosinophil e\nProportion in paints with asthma was S4 + G6\nws othe etn. ths reopen aaa 49 4 Os\n',
#   'japanese cedar, Japanese cypress and mites was affected by the\nte pk aah eee\n\nTal gE Formopaead\nik) _propertion (3)\n\nSpring andl olene meio 52409\n\nSpring pollens and perennial llrgens 391867 54405\n']}

# %%
import pickle
import numpy as np
import faiss
import pandas as pd
from sentence_transformers import SentenceTransformer
from IPython.display import display, HTML 

# Initialize the model and tokenizer : Here we are using paraphrase-MiniLM-L6-v2 for embedding
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
tokenizer = model.tokenizer

# This is to get the maximum number of tokens a given Transformer can take in
max_tokens = model.get_max_seq_length()

# Function to split text into chunks as if a given parahgraph / a piece of text exceeds the maximum number of tokens a Transformer can accept
def split_into_chunks(text, max_length):
    tokens = tokenizer.tokenize(text)
    chunks = []
    for i in range(0, len(tokens), max_length):
        chunk = tokenizer.convert_tokens_to_string(tokens[i:i + max_length])
        chunks.append(chunk)
    return chunks

# Load data from the dictionary
encoded_texts = []
metadata = []

for imageText_filename, text_list in fileText_dict.items():  # Iterate over items in the dictionary
    document_id = imageText_filename[:-4]  # Extract document ID (remove '.pkl')

    for parahnum,text in enumerate(text_list):
        # Convert non-string text elements
        if not isinstance(text, str):
            if isinstance(text, list):
                text = ' '.join(text)
            else:
                text = str(text)

        # Split text into chunks with space for metadata
        chunks = split_into_chunks(text, max_tokens - 20)

        # Encode chunks with metadata
        for chunk_num, chunk in enumerate(chunks):
            chunk_with_metadata = f"{document_id}_parah{parahnum}_chunk{chunk_num}: {chunk}"
            chunk_embedding = model.encode(chunk_with_metadata)
            encoded_texts.append(chunk_embedding)
            metadata.append({
                "document_id": document_id,
                "chunk_number": chunk_num,
                "text_chunk": chunk,
                "parahnum":parahnum
            })

# Create FAISS index outside the loop for efficiency
embeddings_array = np.vstack(encoded_texts) 
embedding_dim = embeddings_array.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings_array)

# Create DataFrame and display
df_metadata = pd.DataFrame(metadata)
display(HTML(df_metadata.to_html(index=False)))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (142 > 128). Running this sequence through the model will result in indexing errors
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>document_id</th>
#       <th>chunk_number</th>
#       <th>text_chunk</th>
#       <th>parahnum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>3. 8. allergic sensitization in asthma. fifty - nine patients ( 46 dul, 18 cildsen ) bad been previously daghosed wih ‘ uthma. the retaining 59 patients had not been diagnosed with sethina sensation to any allergen was deteed in 58 % of patents with asthma ( 34 / 59 ). twenty - six ( 4 % ) of 59 paints wore sensitized to spring pollens ( table 3 ) ‘ approtimatly all of the asthma patients ( 30 % ; 30 /</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>1</td>
#       <td>9 ) were senlzed to perennial allergens. seven percent of patients with asthmns ( 4 / 59 ) were sensitized only to spring.</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>total igi eosinophe cer ik ) _ propertion ( 3 ) spring andl olen meio 52409 springpllensandperenialalrgens 391467 s405, fallen nd prea allergens</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>4. discussion allesglesesitcton, as diagnosed by the serum allergen fpecte igh level does not always correspond with the pallets symptoms, we found that approximately twice a any patients were senalzed ta both spring pollens and petenal allergens compared to patente senatied ony to { pring pollens. however many patients were asymplomatie 1g perehnial allergens expose to perennial allergens such ‘ house dist mite and ct and dog</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>1</td>
#       <td>danduf tan important predisposing rise factor for asthita ( 4, previous dlngosis [ tas wae largely elated to serum ig levels and blood cecinophil conte [ 5 - 7 ], even ln noeasthenatic. patients,</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>‘ the average of total serum ig levee was highest in 87 - year olds and decreased with age figure 3a ) 234, blood call eosinophil count. the blood cll eosinophil unt was alto compared between groups. the ensngphil ‘ all proportion was 43 £ 04 % in pallens senstized only to spring poles, whe it was sigeanly higher ( 57 = 04 % ) it pleats senaltized to bath perenoal allergens and</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>1</td>
#       <td>sping pollens ( p = 00145, mann - whitney u text ) ( igure 20 ), { able 2 ). the blood cell eosinophil count showed the same reductive tendency ( figure 30 ).</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>basinopils counts ( oo7 ). even in nonast mane ppanents : frway responsiveness ( assesed using methacholine [ 8 is increased in some eases of allergic shunts ndieatng an ‘ ncreased risk for asthma [ 9 - h ] sensitization o cat dandr uf shust mite cockroach, and ragweed ian important predictor ‘ fara bypertesponsivenes [ 2 airway hypetesponiv ‘ ess atong</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>1</td>
#       <td>##ly related to elevated ttl ser ig level ‘ en in anymplomalic pallens [ 5, 1 ]. in other words, total serum ig level te considered an indcator of probable airway iyperesponsiveness oe asthma in our study tot serum [ ge level and blood cell eosinophil counts wer sigacaty slevated in patients senstzed to both spring pollens and perennial allergens, as compared to pallet senalized only ‘ os</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>2</td>
#       <td>##pring plles. therefore paint sensitized bth sping pollens and perennial allergens might be at gretter risk of eeveoping arwsybyperresponsivenersor asthma ‘ comnpzed toads, fewer children were sensitized only to spring pollens. most children ( approximately 80 % ) had</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>‘ significantly highe to asee hae</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>‘ spring and fall pollens and perennial</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>‘ with asthma, mann - whitney u test ). blood eosinophil cell proportion in paints with adhe war s4 + g6 % in pallets without ssn, the proportion was 29 + " 02 %,</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>pollen, whe 16 % ( 94 / 59 ) in patients without asthma were fenstzad exclusively totheae allergens. they seven perce fof patents wth previous asthma dlagnoss ( 2159 ) were ‘ esstzed wo both spring nd perennilalergns, which was ficote the te of entiation ( determined by rast ) ignifcantly higher than tat observed in patients without tapanese cedar, japanese cypress, and mites was affected by the 5</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>1</td>
#       <td>##shans ( 2qhi 17 / 993 ) ( p 0. 0017, chi - squize tet )</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>PMC3576793_00004</td>
#       <td>0</td>
#       <td>tait 2 serum total ige and blood cell eosinophil,</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>0</td>
#       <td>perennial allergens compared to patients sensitized only to { pring pollens. however many pants wee asympomatic 1b perennial allergens. exposure to perennial lerens, such ashouse dust mite and cl and dog dandruf an portant predisposing factor fr asta [ 4 ], previous dagnoss santa was largely rated fo serum ge levels ad hood fosinophit counts 5 - 7 ) even in nonasthnaic pants, sway sespnsivenens</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>1</td>
#       <td>( sessed using methacholine [ 5 ineretied in ome cases of allergle thins indesign ‘ ncreased risk for asthma [ 9 - h ] sensitization o cat dandr uf airway byprtesponavenes [ 2 alrwayhypertesponsive fess is suongly related to elevated total serum ige levels</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>0</td>
#       <td>proportion in patients with asthma was s4 + @ 6 %. in pallets without ssn, the proportion was 29 + " 02 %, flood eosinophil cell proportion it patente with aha was signcantly higher than those in patient without asthna ( p = 0008, mans - whitneyu test ) 4. discussion allesglesesitcton, as diagnosed by the serum allergen fpecte igh level does not always correspond with the pallets symptoms, we found that approximately twice</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>1</td>
#       <td>a fran patients were senatied to both spring pollens and</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>0</td>
#       <td>‘ the average of total serum ig levee was highest in 87 - year olds and decreased with age figure 3a ) 234, blood call eosinophil count. the blood cll eosinophil unt was alto compared between groups. the ensngphil ‘ all proportion was 43 £ 04 % in pallens senstized only to spring poles, whe it was sigeanly higher ( 57 = 04 % ) th patents senalied to both perennial al</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>0</td>
#       <td>cetients mee black error ioewed. anne myer forest pond lock orem on reo hp ) uf = gl ) 7, ch - eagmane best ). fate age. bac arrow bea, gay arow hed ; and black arrow yen gal serum ige levels patients with asthma were owe pas och rats peste 4477 + 491uiml, while those inpatient without asthma</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>PMC3654277_00006</td>
#       <td>0</td>
#       <td>pollens ( p = 0. 0146, mann - whitney u test ) ( figure 2 ( b ), { able 2 ). the blood cell eosinophil c
